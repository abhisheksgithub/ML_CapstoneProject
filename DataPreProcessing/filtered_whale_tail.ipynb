# %%
import os

def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)
    return None

p = find('0000e88ab.jpg', r'E:\DownloadedPictures\temp\a' )
print(p)
# Out:
# E:\DownloadedPictures\temp\a\0000e88ab.jpg

# %%
import pandas as pd
xl = pd.read_csv(r'E:\DownloadedPictures\all\train.csv')
xl
# Out:
#                Image         Id
# 0      0000e88ab.jpg  w_f48451c
# 1      0001f9222.jpg  w_c3d896a
# 2      00029d126.jpg  w_20df2c5
# 3      00050a15a.jpg  new_whale
# 4      0005c1ef8.jpg  new_whale
# 5      0006e997e.jpg  new_whale
# 6      000a6daec.jpg  w_dd88965
# 7      000f0f2bf.jpg  new_whale
# 8      0016b897a.jpg  w_64404ac
# 9      001c1ac5f.jpg  w_a6f9d33
# 10     001cae55b.jpg  w_581ba42
# 11     001d7450c.jpg  new_whale
# 12     00200e115.jpg  new_whale
# 13     00245a598.jpg  new_whale
# 14     002b4615d.jpg  new_whale
# 15     002f99f01.jpg  new_whale
# 16     00355ff28.jpg  w_cb622a2
# 17     00357e37a.jpg  w_d3b46e7
# 18     003795857.jpg  new_whale
# 19     0041880bf.jpg  new_whale
# 20     0043da555.jpg  new_whale
# 21     00442c882.jpg  w_8cad422
# 22     00464ff65.jpg  new_whale
# 23     004775679.jpg  w_13ae3d4
# 24     004ae9e26.jpg  new_whale
# 25     004c0f43b.jpg  new_whale
# 26     004e8ad5b.jpg  w_3de579a
# 27     004f87702.jpg  w_1d0830e
# ...

# %%
import shutil
# 25361 9664 15697
item_present = None
for i in range(len(xl)):
    if xl['Id'][i] != 'new_whale':
        item_present = None
        item_present = find(xl['Image'][i], r'E:\DownloadedPictures\all\train' )
        if item_present != None:
            shutil.move(item_present,r"E:\DownloadedPictures\all\train_filtered" + "\\" + xl['Image'][i])
